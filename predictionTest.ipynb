# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\aimva\OneDrive\Desktop\houseprices(Sheet1).csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area, df.price, color = 'red', marker = 'x')
plt.plot(df.area, reg.predict(df[['area']]), color = 'blue')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
prediction = reg.predict(np.array([[5000]]))  # Reshape the scalar value to a 2D array
prediction
# Out:
# c:\Users\aimva\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
135.78767123 * 5000 + 180616.43835616432
# Out:
# 859554.7945061643

# %%
d = pd.read_csv(r"C:\Users\aimva\OneDrive\Desktop\housearea(Sheet1).csv")
d
# Out:
#     area
# 0   2600
# 1   3000
# 2   3200
# 3   3600
# 4   4000
# 5   5400
# 6   3456
# 7   3577
# 8   7644
# 9   6543
# 10  5678
# 11  4587
# 12  5784
# 13  6878
# 14  4667
# 15  4456
# 16  5674
# 17  3567
# 18  6654

# %%
p = reg.predict(d)
p
# Out:
# array([ 533664.38356164,  587979.45205479,  615136.98630137,
#         669452.05479452,  723767.12328767,  913869.8630137 ,
#         649898.63013699,  666328.93835616, 1218577.39726027,
#        1069075.17123288,  951618.83561644,  803474.48630137,
#         966012.32876712, 1114564.04109589,  814337.5       ,
#         785686.30136986,  951075.68493151,  664971.06164384,
#        1084147.60273973])

# %%
d['prices'] = p
d.to_csv('prediction.xlsx', index=False)
d
# Out:
#     area        prices
# 0   2600  5.336644e+05
# 1   3000  5.879795e+05
# 2   3200  6.151370e+05
# 3   3600  6.694521e+05
# 4   4000  7.237671e+05
# 5   5400  9.138699e+05
# 6   3456  6.498986e+05
# 7   3577  6.663289e+05
# 8   7644  1.218577e+06
# 9   6543  1.069075e+06
# 10  5678  9.516188e+05
# 11  4587  8.034745e+05
# 12  5784  9.660123e+05
# 13  6878  1.114564e+06
# 14  4667  8.143375e+05
# 15  4456  7.856863e+05
# 16  5674  9.510757e+05
# 17  3567  6.649711e+05
# 18  6654  1.084148e+06
